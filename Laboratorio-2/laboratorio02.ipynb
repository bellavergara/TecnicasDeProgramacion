# %% [markdown]
# jercicio 1
# Trabajando con la función print()
# El comando print(), el cual es una de las directivas más sencillas de Python, simplemente imprime una
# línea de texto en la pantalla.
# a) Utiliza la función print() para imprimir la linea ¡Hola, Mundo! en la pantalla. Usa comillas dobles
# alrededor de la cadena.
# b) Habiendo hecho eso, usa la función print() nuevamente, pero esta vez imprime tu nombre.
# c) Elimina las comillas dobles y ejecuta tu código. Mira la reacción de Python. ¿Qué tipo de error
# arroja?
# d) Luego, elimina los paréntesis, vuelve a colocar las comillas dobles y ejecuta tu código
# nuevamente. ¿Qué tipo de error arroja esta vez?

# %%
print("hola mundo!")
# Out:
# hola mundo!

# %% [markdown]
# Ejercicio 2
# Modifica la primera línea de código, usando las palabras claves reservadas sep y end, para que se
# obtenga la salida esperada. Emplea dos funciones print() en el editor.
# No cambies nada en la segunda invocación del print().

# %%
print("programing","essentials","in",sep=" ",end=" ")
print ("python")
# Out:
# programing essentials in python

# %% [markdown]
# Ejercicio 3
# Escriba un fragmento de código de una línea, utilizando la función print(), así como los caracteres de
# nuevalínea y de escape, para que coincida con el resultado esperado que se muestra en la salida.

# %%
print("hola\n Mundo\n\"programacion\"")
# Out:
# hola
#  Mundo
# "programacion"

# %% [markdown]
# Ejercicio 4
# ¿Qué tipos de literales son los siguientes ejemplos?
# a) "Hola ", "007"
# b) "1.5", 2.0, 528, False

# %% [markdown]
# a) cadena de texto

# %% [markdown]
# b)cadena de  String

# %% [markdown]
# c) Cadena de string

# %% [markdown]
# 2.0 = flotante

# %% [markdown]
# 528 = Entero

# %% [markdown]
# false = booleano

# %% [markdown]
# Ejercicio 5
# Millas y kilómetros son unidades de longitud o distancia.
# Teniendo en mente que 1 milla equivale aproximadamente a 1.61 kilómetros, realiza un programa que
# devuelva la siguiente salida:
# Convierte de Millas a kilómetros.
# Convierte de Kilómetros a millas.
# Ayuda: utiliza la funcion round para redondear a 2 digitos.

# %%
print("Convierte de Millas a kilometros")
millas = float(input("ingrese millas, por favor:"))
kilometros =round( millas * 1.61,2)
print("El resultado es:", kilometros)

print("Convierte de kilometros a miillas")
kilometros = float(input("ingrese kilometros,por favor:"))
millas = round(kilometros /1.61,2)
print("El resultado es:",millas)
# Out:
# Convierte de Millas a kilometros
# El resultado es: 48.3
# Convierte de kilometros a miillas
# El resultado es: 6.21

# %% [markdown]
# Ejercicio 6
# Observa el código en el editor: lee un valor float, lo coloca en una variable llamada x, e imprime el
# valor de la variable llamada y. Tu tarea es completar el código para evaluar la siguiente expresión:
# El resultado debe ser asignado a y.
# Ayuda: cambia el tipo de dato para asegurarnos de que x es del tipo float.
# Resultado esperado

# %%
X = float(input("ingrese el valor de X:"))
y = 3 * X**3 - 2 * X**2 + 3 * X - 1
print("El resultado es :",y)
# Out:
# El resultado es : 71.0

# %% [markdown]
# Ejercicio 7
# Responde las siguientes preguntas
# a) ¿Cuál es la salida del siguiente fragmento de código?

# %% [markdown]
# 1. 3
# 2. 2
# 3. 5

# %% [markdown]
# el corecto es 1 = 3

# %%
var = 2 
var = 3
print(var)
# Out:
# 3

# %% [markdown]
# b) ¿Cuáles de los siguientes nombres de variables son ilegales/incorrectas en Python?
# 1. my_var
# 2. m
# 3. 101
# 4. averylongVariablename
# 5. m101
# 6. m 101
# 7. Del
# 8. del

# %% [markdown]
# 3,6,8

# %% [markdown]
# c) ¿Cuál es el resultado del siguiente fragmento?

# %% [markdown]
# 1. 1
# 2. 11
# 3. 2
# 4. Error

# %%
a = '1'
b = "1"
print(a+b)
# Out:
# 11

# %% [markdown]
# d) ¿Cuál es el resultado del siguiente fragmento?

# %% [markdown]
# 1. 1.0
# 2. 1
# 3. 9
# 4. 6
# 5. 6.0

# %%
a = 6
b = 3
a = a / (2* b)
print(a)

# %% [markdown]
# Ejercicio 8
# Responde las siguientes preguntas
# a) El dígrafo \n obliga a la función print() a:
# 1. realizar un salto de línea
# 2. imprimir exactamente dos caracteres: \ y n
# 3. duplicar el carácter al lado del dígrafo
# 4. detener su ejecución

# %% [markdown]
# Respuesta correcta : 1. realizar un salto de linea

# %% [markdown]
# b) El significado del parámetro de palabra clave está determinado por:
# 1. el nombre del argumento especificado junto con su valor
# 2. su posición dentro de la lista de argumentos
# 3. su conexión con las variables existentes
# 4. es valioso

# %% [markdown]
# Respuesta correcta : 1

# %% [markdown]
# 1. realiza exponenciación

# %% [markdown]
# d) El resultado de dividir 1/1 es:
# 1. es igual a 1.0
# 2. es igual a 1
# 3. no puede ser evaluado
# 4. no se puede predecir

# %% [markdown]
# 1. es igual a 1.0

# %% [markdown]
# e) ¿Cuál es el resultado del siguiente fragmento?
# print(x,y)

# %% [markdown]
# 1. 2 1
# 2. 1 2
# 3. 1 1
# 4. 2 2

# %% [markdown]
# Respuesta correcta : 1

# %%
x = 1
y = 2
z = x
x = y
y = z
print(x,y)
# Out:
# 2 1

# %% [markdown]
# Ejercicio 9
# Realizar la carga de dos números enteros por teclado e imprimir su suma y su producto.

# %%
numero1 = int(input("ingrese el primer numero :"))
numero2 = int(input("ingrese el segundo numero:"))
suma = numero1 + numero2
producto = numero1 * numero2
print("la suma es:",suma)
print("el producto es:",producto)
# Out:
# la suma es: 25
# el producto es: 150

# %% [markdown]
# Ejercicio 10
# Realizar la carga del precio de un producto y la cantidad a llevar. Mostrar cuanto se debe pagar (se
# ingresa un valor entero en el precio del producto).

# %%
precioproducto = int(input("ingrese el precio del producto:"))
cantidad = int(input("ingrese la cantidad de productos:"))
total = precioproducto * cantidad
print("el total a pagar es:",total)
# Out:
# el total a pagar es: 200

# %% [markdown]
# Ejercicio 11
# Realizar la carga del lado de un cuadrado, mostrar por pantalla el perímetro del mismo (El perímetro
# de un cuadrado se calcula multiplicando el valor del lado por cuatro)

# %% [markdown]
# Ejercicio 12
# Escribir un programa en el cual se ingresen cuatro números, calcular e informar la suma de los dos
# primeros y el producto del tercero y el cuarto.

# %%
numero1 = int(input("ingrese el primero numero:"))
numero2 = int(input("ingrese el segundo numero:"))
numero3 = int(input("ingrese el tercer numero:"))
numero4 = int(input("ingrese el cuarto numero:"))
suma = numero1 + numero2
producto = numero3 * numero4
print("la suma es :",suma)
print("el producto es :",producto)
# Out:
# la suma es : 3
# el producto es : 25

# %% [markdown]
# Ejercicio 11
# Realizar la carga del lado de un cuadrado, mostrar por pantalla el perímetro del mismo (El perímetro
# de un cuadrado se calcula multiplicando el valor del lado por cuatro)

# %%
ladoACudrado = int(input("ingrese el dado del cuadrado:"))
perimetro = ladoACudrado *4
print(" el perimetro de el cuadrado es:",perimetro)
# Out:
#  el perimetro de el cuadrado es: 8

# %% [markdown]
# Ejercicio 13
# Realizar un programa que lea cuatro valores numéricos e informar su suma y promedio.

# %%
valor1 = int(input("ingrese el primer valor:"))
valor2 = int(input("ingrese el segundo valor:"))
valor3 = int(input("ingrese el tercer valor:"))
valor4 = int(input("ingrese el cuarto valor:"))
suma = valor1 + valor2 + valor3 + valor4
promedio = suma /4
print("la suma es:",suma, "y el promedio es:",promedio)
print(f"la suma es: {suma} y el promedio es: {promedio}")
# Out:
# la suma es: 8 y el promedio es: 2.0

# %% [markdown]
# Ejercicio 14
# Calcular el sueldo mensual de un operario conociendo la cantidad de horas trabajadas y el valor por
# hora.

# %%
horasTrabajadas = int(input("ingrese las horas trabajadas:"))
valorHora = int(input("ingrese el valor de la hora:"))
sueldo = horasTrabajadas * valorHora
print("el sueldo por mes es",sueldo)
# Out:
# el sueldo por mes es 200

# %% [markdown]
# Ejercicio 15
# Escribir un programa que muestre por pantalla el resultado de la siguiente operación aritmética

# %%
resultado = ((3+2 )/ 2.5) **2
print(resultado)
# Out:
# 4.0

# %% [markdown]
# Ejercicio 16
# Escribir un programa que lea un entero positivo, introducido por el usuario y después muestre en
# pantalla la suma de todos los enteros desde 1 hasta n. La suma de los primeros enteros positivos
# puede ser calculada de la siguiente forma:

# %%
n = int(input("ingrese un numero entero positivo:"))
suma = n * (n +1) //2
print("la suma de todos los enteros desde 1 hasta",n, "es:",suma)
# Out:
# la suma de todos los enteros desde 1 hasta 50 es: 1275

# %% [markdown]
# Ejercicio 17
# Escribir un programa que pida al usuario dos números enteros y muestre por pantalla la <n> entre
# <m> da un cociente <c> y un resto <r> donde <n> y <m> son los números introducidos por el usuario, y
# <c> y <r> son el cociente y el resto de la división entera respectivamente.

# %%
n = int(input("ingrese el primer numero entero:"))
m= int(input("ingrese el segundo numero entero:"))
c = n // m
resto = n % m
print(f"la division entera de {n} entre {m} es {c} y el resto es {resto}")
# Out:
# la division entera de 2 entre 8 es 0 y el resto es 2

# %% [markdown]
# Ejercicio 18
# Una juguetería tiene mucho éxito en dos de sus productos: payasos y muñecas. Suele hacer venta por
# correo y la empresa de logística les cobra por peso de cada paquete así que deben calcular el peso de
# los payasos y muñecas que saldrán en cada paquete a demanda. Cada payaso pesa 112 g y cada
# muñeca 75 g. Escribir un programa que lea el número de payasos y muñecas vendidos en el último
# pedido y calcule el peso total del paquete que será enviado.

# %%
pesoPayaso= 112
pesomuñecas = 75
payasosVendidos = int(input("ingrese la cantidad de payasos vendidos:"))
muñecasVendidas = int(input("ingrese la cantidad de muñecas vendidas:"))
pesoTotalPayasos= (pesoPayaso * payasosVendidos)
pesototalmuñecas = (pesomuñecas * muñecasVendidas)
pesototal = pesoTotalPayasos +pesototalmuñecas
print("el peso total del paquete a enviar es:",pesototal)
# Out:
# el peso total del paquete a enviar es: 449

# %% [markdown]
# Ejercicio 19
# Una panadería vende barras de pan a $3.49 cada una. El pan que no es el día tiene un descuento del
# 60%. Escribir un programa que comience leyendo el número de barras vendidas que no son del día.
# Después el programa debe mostrar el precio habitual de una barra de pan, el descuento que se le hace
# por no ser fresca y el costo final total.

# %%
panQueNosondelDia = int(input("ingrese la cantidad de pan que fueron vendidos:"))
precioXPan = 3.49
descuento = 0.6

precioConDescuento = precioXPan *(1 - descuento)

costoFinal = panQueNosondelDia * precioConDescuento
print(f"el costo habitual de un pan es {precioXPan}")
print(f"el descuento es {precioConDescuento} ") 
print(f"el costo final es {costoFinal}")
# Out:
# el costo habitual de un pan es 3.49
# el descuento es 1.3960000000000001
# el costo final es 13.96

# %% [markdown]
# Ejercicio 20
# Escribir un programa que pregunte el nombre del usuario en la consola y un número entero e imprima
# por pantalla en líneas distintas el nombre del usuario tantas veces como el número introducido.

# %%
nombre = input("ingrese su nombre:")
numeroEntero = int(input("ingrese un numero entero:"))
for _ in range(numeroEntero):
    print(nombre)
# Out:
# bella
# bella

# %% [markdown]
# Ejercicio 21
# Se desea calcular la distancia recorrida (m) por un móvil que tiene velocidad constante (m/s) durante
# un tiempo t (s), considerar que es un MRU (Movimiento Rectilíneo Uniforme).
# Se sabe que el cálculo de la velocidad en MRU es por formula:
# Despejando la distancia se tiene: 𝑫=𝑽 𝒙 �

# %%
velocidad = float(input("ingrese la velocidad en metros por segundo (m/s):"))
tiempo = float(input("ingrese el tienpo en segundo (s):"))

distancia = velocidad * tiempo
print(f"la distancia recorrida es {distancia}metros.")
# Out:
# la distancia recorrida es 20.0metros.

# %% [markdown]
# Ejercicio 22
# Elaborar un algoritmo que permita ingresar el número de partidos ganados, perdidos y empatados,
# por ABC club en el torneo apertura, se debe de mostrar su puntaje total, teniendo en cuenta que por
# cada partido ganado obtendrá 3 puntos, empatado 1 punto y perdido 0 puntos.

# %%
PartidosGanados = int(input("ingresa el numero de partidos ganados:"))
PartidosPerdidos = int(input("ingrese el numero de partidos perdidos:"))
PartidosEmpatados = int(input("ingrese el numero de partidos empatados:"))

puntajeTotal = (PartidosGanados *3) +(PartidosEmpatados *1) + (PartidosPerdidos*0)
print(f"el puntaje tttal del partido es {puntajeTotal} puntos.")
# Out:
# el puntaje tottal del partido es 11 puntos.
